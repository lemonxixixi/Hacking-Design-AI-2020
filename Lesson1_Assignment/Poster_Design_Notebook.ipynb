# %%
#针对杂志封面的智能海报设计架构
class Poster_Design:
    def __init__(self, img):
        self.img = img
        
# 将图片文件放入代码文件目录内,对图片数据进行读取、预览和剪裁处理：
    def display(self.img): 
        print(“打印预览图片至用户界面”)
        pass
    
    def pic_crop(self.img):
        user_respone = 'N'
        while user_respone = 'N': 
        print("当前加载的图片进行剪裁操作:")
        pass
        print("操作后显示预览效果:")
        display(revised_img)
        user_respone = input(“>>>是否保存当前图片：Y or N ？”)
        self.img = revised_img
        
    def words_input(self):
        print(“>>>读取*.txt文案文件...”)
        f = open(file_name,'r')
        lst_words = []
        lines = f.readlines()       # 逐行读取txt文件，并将每一行文案写入列表中
        for line in lines:
            lst_words.append(line)
        f.close()
        return(lst_words)  #将读取的文案保存为列表并返回

    def words_AiMatch(self,lst_words):
        print("对文案列表进行智能匹配")
        text_form_dict = {}
        for text in lst_words:
            #根据智能匹配的代码块进行权重评测：将该text匹配到合适的文本类型
            #最终返回一个字典：键是text内容，值是相应可能的文本类型列表（杂志名称、主标题、副标题01、副标题02...）
            #每一个文本类型后面对应着相应的字体、字号、格式的模板库
            text_form_dictdict[text] = ['title']

        for text,form in text_form_dict.items():
            respone = input(f"当前该文案如下：{text}\n系统智能匹配为{form}\n 请确认当前文案的文本类型是否合适：Y or N ?)
            if respone = 'Y':
                continue
            else:
                form = input('该文本类型为：')
                text_form_dict[text].clear
                text_form_dict[text].append(form)           
        return text_form_dict

    def pic_analysis(self,img):
        #三个内置函数分别返回针对图片主体、主题、风格的三个参数值：
        def body_aly():
            return body
        def topic_aly():
            return topic                
        def style_aly():
            return style
                            
        body_aly()
        topic_aly()
        style_aly()
        return [body,topic,style]
    def text_analysis(self,text_form_dict):
        for text,form in text_form_dict.items():
            #生成每一条text的主题、传达受众的值，并将其添加到text_form_dict字典中相应的值列表中
            pass
        return text_form_dict
    
    def design(self, text_form_dict, pic_result):
        design_solutions = {}
#   输出文本设计字典：key为每个text内容，值为包含该文本对应的字体格式的字典（字体、大小、粗细）、配色、字符框位置。
#         
        pass
#   design_solutions = {
#                        'design_01(方案1的属性字典)':{'text_第一条文案':{ 'font_name':'Arial',
#                                                 'font_size': 14,
#                                                 'font_weight': 'thin'
#                                                 'color': [213,73,23]
#                                                 'location':[341,222] }
#                                     'text_第二条文案'：{...}
#                                       ....其余文案的属性字典
#                                     }
#                             其余设计方案的属性字典....    
#                             }
        return design_solutions
    def draw_design(self,design_solutions):
#       解包设计方案的字典
#       绘图
#       预览每一个设计图
        pass
    
    def user_customize(self,design_solution):
#   用户对当前设计方案参数进行个性化调整，并保存输出最终的设计方案字典
        pass

# 串联以上功能，执行智能设计的类
def make_design():
                            
#   加载并预览图片，对图片进行剪裁处理并保存
    self.display(self.img)
    self.pic_crop(self.img)
    
#   输入文案txt，并将文案逐行保存在一个文案列表中
    self.words_input()
    
#   对文案列表匹配合适的文本类型，并让用户对其进行修改和确认。
#   返回一个储存每个文案-类型的字典
    self.words_AiMatch()
    
#   对图片进行分析，并返回[body,topic,style]列表赋值给pic_design_data
    pic_design_data = self.pic_analysis(self.img):
        
#   对文本进行分析，并将分析的属性值添加到text_form_dict字典里每个text的值列表中，并返回该文本属性字典
    text_form_dict = self.text_analysis(text_form_dict):
                            
#   输入文本属性字典和图片设计列表到design函数，并生成一系列设计方案的列表。 
    design_solutions = self.design(text_form_dict, pic_design_data)
                            
#   根据设计方案预览效果
    self.draw_design(design_solutions)
                            
#   用户是否选择其中一种设计方案，判断是否进行局部调整，返回最终的设计方案字典。
    choose_design = input("please choose which design to make further actions? design_01/design_02...")
    make_furtherImprove = input("Do you want to customize the poster by yourself? Y/N")
    
    if make_furtherImprove == 'Y':
        final_solution = self.user_customize(design_solution)
    elif make_furtherImprove == 'N':
        final_solution = choose_design
    return final_solution

#  对设计方案进行渲染输出并保存
def output(self,final_solution):
    pass
# Out:
#   File "<ipython-input-6-1dce7e493244>", line 6
#     def display(self.img):
#       ^
# IndentationError: expected an indented block

# %%
test = Poster_Design(img = '')
test.output(test.make_design())
